# %% [markdown]
# # 01 — Exploration
#
# Replace this notebook with your exploratory analysis.
#
# Goal: understand the data, check quality issues, and note early hypotheses.

# %%
from pathlib import Path

DATA_DIR = Path("../data")
RAW_DIR = DATA_DIR / "raw"
PROCESSED_DIR = DATA_DIR / "processed"

RAW_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

print("Project paths ready:", RAW_DIR.resolve())
