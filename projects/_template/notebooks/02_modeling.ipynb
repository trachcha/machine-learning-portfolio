# %% [markdown]
# # 02 — Modeling
#
# Train, evaluate, and compare models. Keep the story clear: baseline → improved model → final metrics.

# %%
# Example skeleton — replace with your modeling pipeline
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report

print("Add your train/eval pipeline here.")
